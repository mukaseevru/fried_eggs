# %% [markdown]
# # Colab setting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Load data

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data"
# Out:
# fried_eggs.csv	test  train  work

# %%
# !rm -rf "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work"
# !mkdir "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work"
# !mkdir "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/train/"

# %%
# !mkdir "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/train/0"
# !cp -rf "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/train/" "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/train/0/unlabeled"

# %%
# !mkdir "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/train/1"
# !cp -rf "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/train/" "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/train/1/unlabeled"

# %%
# !mkdir "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/train/2"
# !cp -rf "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/train/" "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/train/2/unlabeled"

# %%
# !mkdir "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/train/3"
# !cp -rf "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/train/" "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/train/3/unlabeled"

# %%
# !mkdir "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/train/4"
# !cp -rf "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/train/" "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/train/4/unlabeled"

# %%
# !mkdir "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/train/5"
# !cp -rf "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/train/" "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/train/5/unlabeled"

# %%
# !mkdir "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/test/"
# !cp -rf "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/test/" "/content/drive/MyDrive/Colab Notebooks/21/friedeggs/data/work/test/unlabeled"
